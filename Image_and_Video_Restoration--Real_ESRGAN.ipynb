# %% [markdown]
# # Real-ESRGAN

# %%
#@title Enviroment
import os, shutil
OUTPUT_DIR = '/content/output' #@param {type:'string'}
if os.path.exists(OUTPUT_DIR):
    os.makedirs(OUTPUT_DIR, exist_ok=True)

# !git clone https://github.com/xinntao/Real-ESRGAN.git
# !pip install -q basicsr facexlib gfpgan ffmpeg-python
# !pip install -r '/content/Real-ESRGAN/requirements.txt'
# !python setup.py develop

# %%
#@title Evaluate
# Arguments
# -n, --model_name: Model names
# -i, --input: input folder or image
# --outscale: Output scale, can be arbitrary scale factore.
# if it is out of memory, try to use the `--tile` option

MODEL = 'realesr-animevideov3' #@param ['RealESRGAN_x4plus', 'RealESRGAN_x4plus_anime_6B', 'realesr-animevideov3']
INPUT = '/content/demo.mp4' #@param {type:'string'}
OUTSCALE = 4 # @param {type:"slider", min:2, max:5, step:0.5}

# !python inference_realesrgan_video.py -n '{MODEL}' -i "{INPUT}" -o "{OUTPUT_DIR}" --outscale $OUTSCALE --face_enhance
